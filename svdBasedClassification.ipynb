# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Classification Testing.

# %%
import sys
print(sys.executable)
# Out:
# /home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/bin/python3.12

# %%
# custom installation for notebook.
# !pip3.12 install nltk
# Out:
# Requirement already satisfied: nltk in /home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: click in /home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/lib/python3.12/site-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/lib/python3.12/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/lib/python3.12/site-packages (from nltk) (4.66.2)

# %%
from src.classification import RNNClassifier
from src.parser import Dataset
from src.Config import SVDConfig

# %%
dataset = Dataset(fileName = "model.pkl", svdLoad = True)
# Out:
# Loaded SVDEmbedding from /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.

# %%
dataset.getData()
# Out:
# Loading data from /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/train.csv.
# |████████████████████████████████████████| 120000/120000 [100%] in 18.0s (6678.0

# %%
# Run only if SVD Embeddings are not precomputed.
dataset.setSVDEmbeddings()
# Out:
# Constructing bidict mapping...
# Creating sparse co-occurence matrix...
# |██▎⚠︎                                    | (!) 6893/120000 [6%] in 4.9s (1395.77
# Computing SVD on sparse co-occurence matrix...
# Initializing SVD Embeddings...
# Saving SVD Embeddings...
# Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# Traceback (most recent call last):
#   File "/home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/src/parser.py", line 149, in getCoocurenceMatrix
#     self.SparseCoOcMatrix = self.__getSparseCoocurenceMatrix__()
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/src/parser.py", line 173, in __getSparseCoocurenceMatrix__
#     sparseMatrix[self.mapping[token], self.mapping[windowToken]] += 1
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/devilunraveled/.pyenv/versions/3.12.2/envs/wordvectorization/lib/python3.12/site-packages/scipy/sparse/_lil.py", line 258, in __setitem__
#     x = self.dtype.type(x)
#         ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/src/parser.py", line 276, in performSVD
#     U,S,Vt = SparseSVD(A = self.SparseCoOcMatrix, k = min(SVDConfig.EmbeddingSize, len(self.vocab) - 1) )
#                            ^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Dataset' object has no attribute 'SparseCoOcMatrix'
# Traceback (most recent call last):
#   File "/home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/src/parser.py", line 363, in setSVDEmbeddings
#     if self.U is None :
#        ^^^^^^
# AttributeError: 'Dataset' object has no attribute 'U'

# %%
dataset.getTestData()
# Out:
# Loading test-data from /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/test.csv.
# |████████████████████████████████████████| 7600/7600 [100%] in 1.1s (6983.42/s)

# %%
trainData = [ (label, tuple(tokenizedSentence)) for label, tokenizedSentence in zip(dataset.labels, dataset.tokenizedData)]
testData = [ (label, tuple(tokenizedSentence)) for label, tokenizedSentence in zip(dataset.testLabels, dataset.testData)]

# %%
trainData[0][1][1]

# %%
print(dataset.getSVDEmbedding(trainData[0][1][1]))

# %% [markdown]
# ### Using SVD Embeddings for Classification

# %%
svdBasedClassifier = RNNClassifier(inputSize=256, embeddingMap=dataset.getSVDEmbedding, 
                                   data=trainData, testData=testData, 
                                   fileName = f"svdClassifier_{SVDConfig.contextWindow}.pt")
svdBasedClassifier.createDataset()
# Out:
# Loaded model from /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/pretrained/svdClassifier_3.pt.
# Using cuda as device.

# %%
svdBasedClassifier.trainModel()
# svdBasedClassifier.loadModel(fileName = svdBasedClassifier.fileName)
# Out:
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# ...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# on 0: Computing SVD on sparse co-occurence matrix...
# on 0: Initializing SVD Embeddings...
# on 0: Saving SVD Embeddings...
# on 0: Saved dataset to /home/devilunraveled/College/Sem6/IntroToNLP/Assignments/WordVectorization/corpus/svdEmbeddings_3.pkl.
# on 0: Could not get SVDEmbeddings, preparing the same...
# on 0: Creating sparse co-occurence matrix...
# |                                        | ▃▅▇ 0/7500 [0%] in 57s (~0s, 0.0/s)

# %%
svdBasedClassifier.evaluation()

# %%
svdBasedClassifier.plotConfusionMatrix(name=f"SVD_{SVDConfig.EmbeddingSize}_{SVDConfig.contextWindow}")
